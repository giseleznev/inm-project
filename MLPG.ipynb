# %%
import numpy
import math
#list of the selected points
n = 9

class Node:
    def __init__(self, nodec, gaussrad, const):
        self.Coordinates = nodec
        self.GausRadius = gaussrad
        self.GausConstant = const

Nodes = []

GausConstants = []
GausRadiuses = []
#Gaussian weight function
def GausWeight(Node, X):
    dist = numpy.linalg.norm(X-Node.Coordinates)
    weight = (math.exp(-(dist/Node.GausConstant)^2) - 
        math.exp(-(Node.GausRadius/Node.GausConstant)**2))/(1 - math.exp(-(Node.GausRadius/Node.GausConstant)**2))
    if dist < Node.GausRadius:
        return weight
    else:
        return 0

def Weight(Node, X):
    return GausWeight(Node, X)

def Weight(Node1, Node2):
    return GausWeight(Node1, Node2.Coordinates)

#MLS basis
#linear basis here
BasisSize = 3

def BasisFunc(i, x):
    if i == 0:
        return 1
    return x[i-1]

def ComputeBasisFunc(Node):
    p = []
    for size in range(BasisSize):
        p.append(size, BasisFunc(Node.Coordinates))
    return p

def ComputeMatriceP(SomeNodes):
    P = []
    for Node in SomeNodes:
        P.append(ComputeBasisFunc(Node))
    return P

def ComputeMatriceW(Neighbour, SomeNodes):
    W = []
    Zeros = numpy.zeros((len(SomeNodes)))
    index = 0
    for Node in SomeNodes:
        Zeros[index] = Weight(Node, Neighbour)
        W.append(Zeros)
        Zeros[index] = 0
        index += 1
    return W

for NodeMain in Nodes:
    NodesNear = [] #determine the nodes located in the domain of defnition of the MLS
    for Node in Nodes:
        if GausWeight(NodeMain, Node.Coordinates) > 0:
            NodesNear.append(Node)
    #MLS approximation
    ShapeFuncs = []
    DerivShapeFuncs = []
    for Neighbour in NodesNear:
        P = numpy.array(ComputeMatriceP(NodesNear))
        W = numpy.array(ComputeMatriceW(Neighbour,NodesNear))
        p = numpy.array(ComputeBasisFunc(Neighbour))
        A = numpy.dot(P.T,numpy.dot(W,P))
        B = numpy.dot(P.T,B)
        fi = numpy.dot(p, numpy.dot(numpy.linalg.inv(A), B)) #check sizes
        ShapeFuncs.append(fi)
